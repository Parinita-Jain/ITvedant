# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("data1.csv")
df.head()
# Out:
#     Name  Python  Machine Learning
# 0    jay    90.0               NaN
# 1    raj     NaN              89.0
# 2  kumar    78.0              78.0
# 3  suraj     NaN               NaN
# 4  pawan     NaN              87.0

# %%
df.info()
# column profiling
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              10 non-null     object
#  1   Python            6 non-null      float64
#  2   Machine Learning  7 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 372.0+ bytes

# %%
(df.isnull().sum()/len(df))*100
# python - 40% missing values
# ml - 30% missing values
# Out:
# Name                 0.0
# Python              40.0
# Machine Learning    30.0
# dtype: float64

# %%
# statistical distribution
df.describe()
# Python - 71.33>74 no - negatively skewed
# ML - 69.85>67.00 yes - positively skewed
# Out:
#           Python  Machine Learning
# count   6.000000          7.000000
# mean   71.333333         69.857143
# std    15.513435         16.087558
# min    45.000000         45.000000
# 25%    66.250000         61.500000
# 50%    74.000000         67.000000
# 75%    79.500000         82.500000
# max    90.000000         89.000000

# %%
sns.kdeplot(df["Python"])
# Out:
# <Axes: xlabel='Python', ylabel='Density'>

# %%
sns.kdeplot(df["Machine Learning"])
# Out:
# <Axes: xlabel='Machine Learning', ylabel='Density'>

# %%
# drop rows
df.dropna() #df=df.dropna()
# Out:
#     Name  Python  Machine Learning
# 2  kumar    78.0              78.0
# 5  viraj    65.0              56.0
# 6  vijay    45.0              67.0
# 7  sumit    80.0              45.0
# 8  akash    70.0              67.0

# %%
df
# Out:
#     Name  Python  Machine Learning
# 0    jay    90.0               NaN
# 1    raj     NaN              89.0
# 2  kumar    78.0              78.0
# 3  suraj     NaN               NaN
# 4  pawan     NaN              87.0
# 5  viraj    65.0              56.0
# 6  vijay    45.0              67.0
# 7  sumit    80.0              45.0
# 8  akash    70.0              67.0
# 9  sujit     NaN               NaN

# %%
#df["Python"].fillna(0)
df["Python"]=df["Python"].fillna(df["Python"].median())

df["Machine Learning"]=df["Machine Learning"].fillna(df["Machine Learning"].median())

# %%
df
# Out:
#     Name  Python  Machine Learning
# 0    jay    90.0              67.0
# 1    raj    74.0              89.0
# 2  kumar    78.0              78.0
# 3  suraj    74.0              67.0
# 4  pawan    74.0              87.0
# 5  viraj    65.0              56.0
# 6  vijay    45.0              67.0
# 7  sumit    80.0              45.0
# 8  akash    70.0              67.0
# 9  sujit    74.0              67.0
