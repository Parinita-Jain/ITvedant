# %% [markdown]
# # Introduction to OpenCV

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading Images

# %% [markdown]
# cv2.IMREAD_COLOR: It specifies to load a color image. Any transparency of image will be neglected. It is the default flag. Alternatively, we can pass integer value 1 for this flag.
#
#
# cv2.IMREAD_GRAYSCALE: It specifies to load an image in grayscale mode. Alternatively, we can pass integer value 0 for this flag.
#
#
# cv2.IMREAD_UNCHANGED: It specifies to load an image as such including alpha channel. Alternatively, we can pass integer value -1 for this flag.

# %%
color_img = cv2.imread(r'C:\Data Science\AI\Computer Vision\1807_ESIEA_ComputerVision-1\OIP.jpg', cv2.IMREAD_COLOR)
gray_img = cv2.imread(r'C:\Data Science\AI\Computer Vision\1807_ESIEA_ComputerVision-1\OIP.jpg', cv2.IMREAD_GRAYSCALE) # gray = cv2.cvtColor(color_img, cv2.COLOR_BGR2GRAY)
alpha_img = cv2.imread(r'C:\Data Science\AI\Computer Vision\1807_ESIEA_ComputerVision-1\UIEBe.png', cv2.IMREAD_UNCHANGED)

# %%
color_img_1 = cv2.imread(r'C:\Data Science\AI\Computer Vision\1807_ESIEA_ComputerVision-1\OIP.jpg', 1)
gray_img_1 = cv2.imread(r'C:\Data Science\AI\Computer Vision\1807_ESIEA_ComputerVision-1\OIP.jpg', 0)
alpha_img_1 = cv2.imread(r'C:\Data Science\AI\Computer Vision\1807_ESIEA_ComputerVision-1\UIEBe.png', -1)

# %%
alpha_img_1.shape
# Out:
# (381, 225, 4)

# %%
color_img.shape
# Out:
# (266, 474, 3)

# %%
gray_img.shape
# Out:
# (266, 474)

# %%
alpha_img.shape
# Out:
# (381, 225, 4)

# %%
color_img
# Out:
# array([[[ 57,  58,  56],
#         [ 57,  58,  56],
#         [ 57,  58,  56],
#         ...,
#         [ 54,  55,  53],
#         [ 52,  53,  51],
#         [ 52,  53,  51]],
#
#        [[ 57,  58,  56],
#         [ 57,  58,  56],
#         [ 57,  58,  56],
#         ...,
#         [ 54,  55,  53],
#         [ 52,  53,  51],
#         [ 52,  53,  51]],
#
#        [[ 58,  59,  57],
#         [ 58,  59,  57],
#         [ 58,  59,  57],
#         ...,
#         [ 55,  56,  54],
#         [ 51,  52,  50],
#         [ 51,  52,  50]],
#
#        ...,
#
#        [[ 92,  85,  88],
#         [ 90,  85,  86],
#         [ 85,  86,  84],
#         ...,
#         [109, 104, 105],
#         [110, 104,  99],
#         [114, 104,  97]],
#
#        [[105,  97,  98],
#         [ 95,  90,  89],
#         [ 88,  87,  83],
#         ...,
#         [110, 106, 105],
#         [115, 109, 104],
#         [120, 112, 105]],
#
#        [[105,  97,  98],
#         [ 95,  90,  89],
#         [ 88,  87,  83],
# ...

# %%
gray_img
# Out:
# array([[ 57,  57,  57, ...,  54,  52,  52],
#        [ 57,  57,  57, ...,  54,  52,  52],
#        [ 58,  58,  58, ...,  55,  51,  51],
#        ...,
#        [ 87,  86,  85, ..., 105, 103, 103],
#        [ 98,  90,  86, ..., 106, 108, 111],
#        [ 98,  90,  86, ..., 106, 108, 111]], dtype=uint8)

# %%
color_img.shape, gray_img.shape, alpha_img.shape
# Out:
# ((266, 474, 3), (266, 474), (381, 225, 4))

# %%
cv2.imshow("Black and White",gray_img)
cv2.imshow("Color",color_img) #5sec
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow("Color",color_img)
cv2.waitKey(5000) #5sec
cv2.destroyAllWindows()

# %%
cv2.imshow("Color",color_img)
if cv2.waitKey(0) & 0xFF == ord('r'):
    cv2.destroyAllWindows()

# %%
cv2.imshow("Color",alpha_img)
if cv2.waitKey(0) & 0xFF == ord('q'):
    cv2.destroyAllWindows()

# %%
plt.imshow(color_img)

# %%
color_img.shape
# Out:
# (266, 474, 3)

# %%
RGB_img = cv2.cvtColor(color_img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)

# %%
cv2.imshow("Color",RGB_img)
cv2.waitKey(5000) #5sec
cv2.destroyAllWindows()

# %% [markdown]
# ## Saving the image

# %%
cv2.imwrite('edited.jpg', color_img)
# Out:
# True

# %% [markdown]
# ## Extracting RGB values of pixels

# %%
import cv2

B, G, R = cv2.split(color_img)
# Corresponding channels are separated

cv2.imshow("blue", B)
cv2.waitKey(0)

cv2.imshow("Green", G)
cv2.waitKey(0)

cv2.imshow("red", R)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ## Extraction Region Of Interest (ROI)

# %%
RGB_img = cv2.cvtColor(color_img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)

# %%
image=cv2.imread(r'C:\Data Science\AI\Computer Vision\1807_ESIEA_ComputerVision-1\OIP.jpg')

# Step 3: Extract the ROI
roi = image[50:155, 350:430]

# Step 4: Display the Original Image and the ROI
# Convert BGR image to RGB for displaying with matplotlib
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
roi_rgb = cv2.cvtColor(roi, cv2.COLOR_BGR2RGB)

plt.title("Region of Interest (ROI)")
plt.imshow(roi_rgb)
plt.show()

plt.imshow(image_rgb)

# %% [markdown]
# ## Extracting height and width of an image

# %%
#reading the image using imread() function

image=cv2.imread(r'C:\Data Science\AI\Computer Vision\1807_ESIEA_ComputerVision-1\OIP.jpg')

#Extracting the height and width of image

h,w=image.shape[:2]

#display the heigh and width

print(f"height = {h} , width = {w}")
# Out:
# height = 266 , width = 474

# %% [markdown]
# ## Resizing the image

# %% [markdown]
# ### Resizing an image can be done in many ways. We will look into examples demonstrating the following resize operations.
#
# 1. Preserve Aspect Ratio (height to width ratio of image is preserved)
#
#   - Downscale (Decrease the size of the image)
#
#   - Upscale (Increase the size of the image)
#
# 2. Do not preserve Aspect Ratio
#
#   - Resize only the width (Increase or decrease the width of the image keeping height unchanged)
#
#   - Resize only the height (Increase or decrease the height of the image keeping width unchanged)
#
# 3. Resize to specific width and height

# %% [markdown]
# **Choice of Interpolation Method for Resizing:**
#
# cv2.INTER_AREA: This is used when we need to shrink an image.
#
#
# cv2.INTER_CUBIC: This is slow but more efficient.
#
#
# cv2.INTER_LINEAR: This is primarily used when zooming is required. This is the default interpolation technique in OpenCV.

# %% [markdown]
# ### 1. Downscale – Resize and Preserve Aspect Ratio

# %%
img = cv2.imread(r'C:\Data Science\AI\Computer Vision\1807_ESIEA_ComputerVision-1\OIP.jpg', 1)

print('Original Dimensions : ',img.shape)

scale_percent = 60 # percent of original size
width = int(img.shape[1] * scale_percent / 100)
height = int(img.shape[0] * scale_percent / 100)
dim = (width, height)

# resize image
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)

print('Resized Dimensions : ',resized.shape)

cv2.imshow("Original",img)
cv2.imshow("Resized",resized)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Original Dimensions :  (266, 474, 3)
# Resized Dimensions :  (159, 284, 3)

# %% [markdown]
# ### 2. Upscale – Resize and Preserve Aspect Ratio

# %%
img = cv2.imread(r'C:\Data Science\AI\Computer Vision\1807_ESIEA_ComputerVision-1\OIP.jpg', 1)

print('Original Dimensions : ',img.shape)

scale_percent = 120 # percent of original size
width = int(img.shape[1] * scale_percent / 100)
height = int(img.shape[0] * scale_percent / 100)
dim = (width, height)

# resize image
resized = cv2.resize(img, dim, interpolation = cv2.INTER_CUBIC)

print('Resized Dimensions : ',resized.shape)

cv2.imshow("Original",img)
cv2.imshow("Resized",resized)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Original Dimensions :  (266, 474, 3)
# Resized Dimensions :  (319, 568, 3)

# %% [markdown]
# ### 3. Resize only width and do not preserve Aspect Ratio

# %%
img = cv2.imread(r'C:\Data Science\AI\Computer Vision\1807_ESIEA_ComputerVision-1\OIP.jpg', 1)

print('Original Dimensions : ',img.shape)

width = 900
height = img.shape[0] # keep original height
dim = (width, height)

# resize image
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)

print('Resized Dimensions : ',resized.shape)

cv2.imshow("Original",img)
cv2.imshow("Resized",resized)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Original Dimensions :  (266, 474, 3)
# Resized Dimensions :  (266, 900, 3)

# %% [markdown]
# ### 4. Resize only height and do not preserve Aspect Ratio

# %%
img = cv2.imread(r'C:\Data Science\AI\Computer Vision\1807_ESIEA_ComputerVision-1\OIP.jpg', 1)

print('Original Dimensions : ',img.shape)

width = img.shape[1] # keep original width
height = 440
dim = (width, height)

# resize image
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)

print('Resized Dimensions : ',resized.shape)

cv2.imshow("Original",img)
cv2.imshow("Resized",resized)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Original Dimensions :  (266, 474, 3)
# Resized Dimensions :  (440, 474, 3)

# %% [markdown]
# ### 5. Resize to specific width and height

# %%
img = cv2.imread(r'C:\Data Science\AI\Computer Vision\1807_ESIEA_ComputerVision-1\OIP.jpg', 1)

print('Original Dimensions : ',img.shape)

width = 350
height = 450
dim = (width, height)

# resize image
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)

print('Resized Dimensions : ',resized.shape)

cv2.imshow("Original",img)
cv2.imshow("Resized",resized)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Original Dimensions :  (266, 474, 3)
# Resized Dimensions :  (450, 350, 3)

# %% [markdown]
# ## Rotating the image

# %%
img = cv2.imread(r'C:\Data Science\AI\Computer Vision\1807_ESIEA_ComputerVision-1\OIP.jpg', 1)
# Calculating the center of the image

h,w = img.shape[:2]

print(w, h)

center = (w // 2, h // 2)


# Generating a rotation matrix

matrix = cv2.getRotationMatrix2D(center, 180, 1.0)


# Performing the affine transformation

rotated = cv2.warpAffine(img, matrix, (w, h))

cv2.imshow("Original",img)
cv2.imshow("Rotated",rotated)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 474 266

# %% [markdown]
# ## Drawing Rectangle

# %%
img = cv2.imread(r'C:\Data Science\AI\Computer Vision\1807_ESIEA_ComputerVision-1\OIP.jpg', 1)

# %%
cv2.imshow("Original",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img)

# %%
rectangle = cv2.rectangle(img, (320, 60),(430, 155), (50, 150, 250), 3)

# %%
plt.imshow(img)

# %%
cv2.imshow("Rectangle",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Writing text over images
#
# Fonts
#
# OpenCV supports the following fonts:
#
# Font Name Font Size
#
# FONT_HERSHEY_SIMPLEX 0
#
# FONT_HERSHEY_PLAIN 1
#
# FONT_HERSHEY_DUPLEX 2
#
# FONT_HERSHEY_COMPLEX 3
#
# FONT_HERSHEY_TRIPLEX 4
#
# FONT_HERSHEY_COMPLEX_SMALL 5
#
# FONT_HERSHEY_SCRIPT_SIMPLEX 6
#
# FONT_HERSHEY_SCRIPT_COMPLEX 7
#
# FONT_ITALIC 16

# %%
img = cv2.imread(r'C:\Data Science\AI\Computer Vision\1807_ESIEA_ComputerVision-1\OIP.jpg', 1)

# Adding the text using putText() function
rectangle = cv2.rectangle(img, (197, 40),

						(270, 140), (255, 230, 120), 3)

text = cv2.putText(rectangle, 'Neeraj Chopra', (197, 30),cv2.FONT_HERSHEY_COMPLEX, 0.6, (255, 0, 0), 2)

cv2.imshow("Text",text)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Video Capture

# %%
cap = cv2.VideoCapture(0)


while(cap.isOpened()):

    # Capture frame-by-frame

    ret, frame = cap.read()

    if ret:

        # Our operations on the frame come here

        # gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        text = cv2.putText(frame, 'Press Q to close the video', (30, 30),cv2.FONT_HERSHEY_COMPLEX, 0.6, (0, 0, 255), 2)


        # Display the resulting frame

        cv2.imshow("Text",text)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    else:
        break


# When everything done, release the capture

cap.release()

cv2.destroyAllWindows()

# %% [markdown]
# ## Saving frames from videos

# %%
import cv2


cap = cv2.VideoCapture(r'C:\Data Science\AI\Computer Vision\1807_ESIEA_ComputerVision-1\vtest.mp4')

i = 0
while(cap.isOpened()):

    ret, frame = cap.read()

    if ret == True:

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        if i%5 == 0:
            cv2.imwrite(f"saved_frames/frame_{i}.jpg", frame)

        cv2.imshow("Text",gray)

        i += 1

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    else:
        break


cap.release()

cv2.destroyAllWindows()

# %% [markdown]
# ## Saving Videos

# %%
import numpy as np

import cv2


cap = cv2.VideoCapture(0)


# Define the codec and create VideoWriter object

fourcc = cv2.VideoWriter_fourcc(*'XVID')

out = cv2.VideoWriter('output.avi',fourcc, 20.0, (640,480))


while(cap.isOpened()):

    ret, frame = cap.read()

    if ret==True:

        frame = cv2.flip(frame,0)


        # write the flipped frame

        out.write(frame)


        cv2.imshow('frame',frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):

            break

    else:

        break


# Release everything if job is finished

cap.release()

out.release()

cv2.destroyAllWindows()

# %% [markdown]
# ## Video from images

# %%
import glob

img_array = []

for filename in glob.glob(r'tennis\*.jpg'):
  img = cv2.imread(filename)
  height, width = img.shape[:2]
  size = (width,height)
  img_array.append(img)

out = cv2.VideoWriter(r'saved_video\video.avi',cv2.VideoWriter_fourcc(*'XVID'), 40, size)

for i in range(len(img_array)):

  out.write(img_array[i])

  cv2.imshow('frame',img_array[i])

  if cv2.waitKey(1) & 0xFF == ord('q'):
    break

out.release()

cv2.destroyAllWindows()

# %% [markdown]
# # Edge Detection

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
img = cv2.imread(r'C:\Data Science\AI\Computer Vision\1807_ESIEA_ComputerVision-1\cats.jpg', 1)

cv2.imshow("Players",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Using Canny

# %%
# Convert the image to grayscale
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Perform edge detection on the image
edges = cv2.Canny(gray_image, threshold1=200, threshold2=250)

cv2.imshow("Edges",edges)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Using Sobel

# %%
img = cv2.imread(r'C:\Data Science\AI\Computer Vision\1807_ESIEA_ComputerVision-1\red_cv.jpg', 1)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Sobel Edge Detection
sobelx = cv2.Sobel(src=img, ddepth=cv2.CV_64F, dx=1, dy=0, ksize=1) # Sobel Edge Detection on the X axis
sobely = cv2.Sobel(src=img, ddepth=cv2.CV_64F, dx=0, dy=1, ksize=1) # Sobel Edge Detection on the Y axis
sobelxy = cv2.Sobel(src=img, ddepth=cv2.CV_64F, dx=1, dy=1, ksize=1) # Combined X and Y Sobel Edge Detection

# Display Sobel Edge Detection Images
cv2.imshow("X axis",sobelx)

cv2.imshow("Y axis",sobely)

cv2.imshow("XY combined",sobelxy)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Template Matching

# %%
import cv2
import numpy as np

img = cv2.imread(r'C:\Data Science\AI\Computer Vision\1807_ESIEA_ComputerVision-1\rl.png', 1)
cv2.imshow("Text",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
template = cv2.imread(r'C:\Data Science\AI\Computer Vision\1807_ESIEA_ComputerVision-1\m.jpg',1)
cv2.imshow("Text",template)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread(r'C:\Data Science\AI\Computer Vision\1807_ESIEA_ComputerVision-1\rl.png', 1)

h,w = template.shape[:2]

matched = cv2.matchTemplate(img,template,5)

min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(matched)

print(min_val, max_val, min_loc, max_loc)

cv2.rectangle(img, max_loc, (max_loc[0] + w, max_loc[1] + h), (0,255,255), 2)

cv2.imshow("Text",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# -0.27295902371406555 0.9986005425453186 (229, 215) (120, 60)

# %% [markdown]
# ## Face Detection

# %%
import numpy as np
import cv2
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

img = cv2.imread(r'C:\Data Science\AI\Computer Vision\1807_ESIEA_ComputerVision-1\rl.png')

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
  cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)

cv2.imshow("Text",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(0)


while(cap.isOpened()):

    # Capture frame-by-frame

    ret, frame = cap.read()

    if ret:

        # Our operations on the frame come here

        # gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        faces = face_cascade.detectMultiScale(gray, 1.3, 5)

        for (x,y,w,h) in faces:
            cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),2)


        # Display the resulting frame

        cv2.imshow("Text",frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    else:
        break


# When everything done, release the capture

cap.release()

cv2.destroyAllWindows()
